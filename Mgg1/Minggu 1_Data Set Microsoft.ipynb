# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import  train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
Microsoft_data = pd.read_csv('gdrive/My Drive/data set/Microsoft.csv')

# %%
Microsoft_data.describe()

# %%
Microsoft_data.columns

# %%
Microsoft_data = Microsoft_data.dropna(axis=0)

# %%
y = Microsoft_data.High
y.describe()

# %%
Microsoft_features = ['Open', 'High', 'Low', ]

# %%
X = Microsoft_data[Microsoft_features]

# %%
X.describe()

# %%
X.head(10)

# %%
X.tail(10)

# %%
Microsoft_model = DecisionTreeRegressor(random_state=1)

# %%
Microsoft_model.fit(X, y)

# %%
print("Make Prediction:")
print(X.head())
print("the prediction")
print(Microsoft_model.predict(X.head()))

# %%
from sklearn.metrics import mean_absolute_error

predicted_High_prices = Microsoft_model.predict(X)
mean_absolute_error(y, predicted_High_prices)

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %%
Microsoft_model = DecisionTreeRegressor()
Microsoft_model.fit(train_X, train_y)

# %%
val_predictions = Microsoft_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))

# %%
from sklearn.metrics import  mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
  model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
  model.fit(train_X, train_y)
  preds_val = model.predict(val_X)
  mae = mean_absolute_error(val_y, preds_val)
  return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
  my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
  print("Max leaf nodes : %d \t\t Mean Absolute Error : %d" % (max_leaf_nodes, my_mae))

# %% [markdown]
# Harus Menggunakan Data Set tipe data FLOAT
