# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %% [markdown]
# Data Set Netflix Tidak bisa digunakan Karena harus membutuhkan Tipe data FLOAT

# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import  train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
netflix_data = pd.read_csv('gdrive/My Drive/data set/netflix_titles.csv')

# %%
netflix_data.describe()

# %%
netflix_data.columns

# %%
netflix_data = Microsoft_data.dropna(axis=0)

# %%
y = netflix_data.type
y.describe()

# %%
netflix_features = ['type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year']

# %%
X = Microsoft_data[Microsoft_features]

# %%
X.describe()

# %%
X.head(10)

# %%
X.tail(10)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
netflix_model = DecisionTreeRegressor(random_state=1)

# %%
netflix_model.fit(X, y)
